# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
xpoints=np.array([0,20])
ypoints=np.array([15,80])
plt.plot(xpoints,ypoints)
plt.show()

# %%
s='HI Three Sam'
li=s.split(" ")
li
# Out:
# ['HI', 'Three', 'Sam']

# %%
def rec(n=1):
    if n>3:
        return n
    print(n+1)
rec(8)
# Out:
# 8
